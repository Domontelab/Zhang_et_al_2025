# %% [markdown]
# # Package

# %%
! pip install cebra

# %%
import sys

import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
import random
import cebra
import cebra.datasets
from cebra import CEBRA
import cebra.grid_search
import time
# Out:
# Requirement already satisfied: cebra in /opt/anaconda3/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (2.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (2.27.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (1.7.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (3.5.1)
# Requirement already satisfied: literate-dataclasses in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (0.0.6)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (1.1.3)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (1.1.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from cebra) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->cebra) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->cebra) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->cebra) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests->cebra) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->cebra) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->cebra) (2.2.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.9/site-packages (from torch->cebra) (1.10.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.9/site-packages (from torch->cebra) (4.5.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from torch->cebra) (2.11.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.9/site-packages (from torch->cebra) (3.6.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.9/site-packages (from torch->cebra) (2.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch->cebra) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from sympy->torch->cebra) (1.2.1)
# /opt/anaconda3/lib/python3.9/site-packages/cebra/datasets/monkey_reaching.py:35: UserWarning: Could not import the nlb_tools package required for data loading of cebra.datasets.monkey_reaching. Dataset will not be available. If required, you can install the dataset by running pip install git+https://github.com/neurallatents/nlb_tools.
#   warnings.warn(

# %% [markdown]
# # 1. Dataset

# %%
Dt = pd.read_csv('1S5.csv')

Time = Dt.iloc[:,0]
Y = Dt.iloc[:, 2]
Label = Dt.iloc[:, 1]
X = Dt.iloc[:,3:61]

# %% [markdown]
# # 2. Visualization from tSNE

# %% [markdown]
# ## (1). Raw data

# %%
color_names = ["purple", "red", "amber", "faded green", "windows blue", "orange"]
colors = sns.xkcd_palette(color_names)
# cmap = gradient_cmap(colors)

plt.figure(figsize=(16, 8))

plt.imshow(X.T, aspect="auto", vmin = 0, vmax = len(colors))
plt.xlabel('Time (s)')
plt.ylabel('# Neurons')
# Out:
# Text(0, 0.5, '# Neurons')

# %% [markdown]
# ## (2). tSNE

# %%
dino_tsne = TSNE(n_components = 2)
dino_tsne_viz = dino_tsne.fit_transform(X)

fig = plt.figure(figsize = (5,5))
plt.scatter(dino_tsne_viz[:,0], dino_tsne_viz[:,1], cmap = 'magma', c = np.arange(X.shape[0]))
plt.axis('off')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (-71.76381225585938, 102.09704895019532, -58.99413795471192, 66.67915840148926)

# %% [markdown]
# # 3. CEBRA-Time Model (Non-supervised)

# %% [markdown]
# ## (1). Demo of CEBRA-Time model

# %%
cebra_time3_model = CEBRA(batch_size = 512,
                          learning_rate = 3e-4,
                          temperature_mode = 'auto',
                          output_dimension = 10,
                          max_iterations = 10000,
                          distance = 'cosine',
                          conditional = 'time',
                          device = 'cpu',
                          verbose = True,
                          time_offsets = 12)
# Fit model
cebra_time3_model.fit(X)
cebra_time3 = cebra_time3_model.transform(X)

# %%
# Model convergence
cebra.plot_loss(cebra_time3_model)

# %%
# Visualization of embedding vectors
cebra.plot_embedding(cebra_time3, embedding_labels = "time", cmap="magma", markersize=5, alpha=0.5)

# %% [markdown]
# ## (2). Training non-supervised CEBRA model

# %% [markdown]
# ### 1). Hyperparameter space

# %%
distance = ['cosine', 'euclidean']                # a: 2
temperature_mode = ['auto']                       # b: 1
time_offsets = [1, 5, 10, 20, 50]                 # c: 5
batch_size = [10, 50, 100, 512, 750]              # d: 5
learning_rate = [0.0001, 0.001, 0.01, 0.1, 1]  # e: 6
conditional = ['time']                            # f: 1
output_dimension = [2, 3, 5, 8, 10, 15, 20]       # g: 7
num_hidden_units = [32, 50, 75]                   # h: 3

max_iterations = [10000]                            # i: 1


# Put into a matrix
Hyperparameter_Space = [(a,b,c,d,e,f,g,h,i) 
                        for a in distance 
                        for b in temperature_mode 
                        for c in time_offsets 
                        for d in batch_size 
                        for e in learning_rate 
                        for f in conditional 
                        for g in output_dimension
                        for h in num_hidden_units
                        for i in max_iterations]
Hyperparameter_Mat = pd.DataFrame(Hyperparameter_Space)
Hyperparameter_Mat.columns = ['distance', 'temperature_mode', 'time_offsets', 'batch_size', 
                              'learning_rate', 'conditional', 'output_dimension', 'num_hidden_units', 'max_iterations']
Hyperparameter_Mat

# %% [markdown]
# ### 2). Training Function

# %%
# Self define training function
def Self_CEBRA_Time_Training(Toy, X):
    # Timer
    start_time = time.time()

    # DataFrame for evaluation metrics
    Performance = pd.DataFrame([])
    InfoNCE = []
    
    n_comb = len(Toy)

    for i in range(0, n_comb):
        # Extract hyperparameter
        Hyper_i = Toy.iloc[i, :]
        Hyperpara = {'distance': Hyper_i['distance'], 
                     'temperature_mode': Hyper_i['temperature_mode'], 
                     'time_offsets': Hyper_i['time_offsets'], 
                     'batch_size': Hyper_i['batch_size'],       
                     'learning_rate': Hyper_i['learning_rate'], 
                     'conditional': Hyper_i['conditional'], 
                     'output_dimension': Hyper_i['output_dimension'], 
                     'num_hidden_units': Hyper_i['num_hidden_units'], 
                     'max_iterations': Hyper_i['max_iterations']}

        # Extract sub-hyperparameters
        cebra_time_model = CEBRA(batch_size = Hyperpara['batch_size'],
                                  learning_rate = Hyperpara['learning_rate'],
                                  temperature_mode = Hyperpara['temperature_mode'],
                                  output_dimension = Hyperpara['output_dimension'],
                                  max_iterations = Hyperpara['max_iterations'],
                                  distance = Hyperpara['distance'],
                                  conditional = Hyperpara['conditional'],
                                  time_offsets = Hyperpara['time_offsets'],
                                  device = 'cuda_if_available',
                                  verbose = False)
        
        # Model fitting
        cebra_time_model.fit(X)
        
        # Model loss function value
        InfoNCELoss = min(cebra_time_model.state_dict_['loss'])
        InfoNCE.append(InfoNCELoss.tolist())

    print("--- %s seconds ---" % (time.time() - start_time))

    # Training performance
    dt = {'Accuracy_Testing': InfoNCE}
    Performance = pd.DataFrame(dt)

    # Combined train and test results
    Combined_Rsult = pd.concat([Toy, Performance], axis = 1)
    return(Combined_Rsult)

# %% [markdown]
# ### 3). Training process

# %%
# Cut hyperparameter space into difference pieces: 10 pieces (0-9)
Hyp_Pieces = np.array_split(range(len(Hyperparameter_Mat)), 10)
len(Hyp_Pieces)

# %%
## 0
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[0], :]
Toy.reset_index(drop = True, inplace = True)
Result_0 = Self_CEBRA_Time_Training(Toy, X)
Result_0.to_csv('CEBRA_Time Training Results 0.csv')

# %%
## 1
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[1], :]
Toy.reset_index(drop = True, inplace = True)
Result_1 = Self_CEBRA_Time_Training(Toy, X)
Result_1.to_csv('CEBRA_Time Training Results 1.csv')

# %%
## 2
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[2], :]
Toy.reset_index(drop = True, inplace = True)
Result_2 = Self_CEBRA_Time_Training(Toy, X)
Result_2.to_csv('CEBRA_Time Training Results 2.csv')

# %%
## 3
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[3], :]
Toy.reset_index(drop = True, inplace = True)
Result_3 = Self_CEBRA_Time_Training(Toy, X)
Result_3.to_csv('CEBRA_Time Training Results 3.csv')

# %%
## 4
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[4], :]
Toy.reset_index(drop = True, inplace = True)
Result_4 = Self_CEBRA_Time_Training(Toy, X)
Result_4.to_csv('CEBRA_Time Training Results 4.csv')

# %%
## 5
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[5], :]
Toy.reset_index(drop = True, inplace = True)
Result_5 = Self_CEBRA_Time_Training(Toy, X)
Result_5.to_csv('CEBRA_Time Training Results 5.csv')

# %%
## 6
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[6], :]
Toy.reset_index(drop = True, inplace = True)
Result_6 = Self_CEBRA_Time_Training(Toy, X)
Result_6.to_csv('CEBRA_Time Training Results 6.csv')

# %%
## 7
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[7], :]
Toy.reset_index(drop = True, inplace = True)
Result_7 = Self_CEBRA_Time_Training(Toy, X)
Result_7.to_csv('CEBRA_Time Training Results 7.csv')

# %%
## 8
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[8], :]
Toy.reset_index(drop = True, inplace = True)
Result_8 = Self_CEBRA_Time_Training(Toy, X)
Result_8.to_csv('CEBRA_Time Training Results 8.csv')

# %%
## 9
Toy = Hyperparameter_Mat.iloc[Hyp_Pieces[9], :]
Toy.reset_index(drop = True, inplace = True)
Result_9 = Self_CEBRA_Time_Training(Toy, X)
Result_9.to_csv('CEBRA_Time Training Results 9.csv')
