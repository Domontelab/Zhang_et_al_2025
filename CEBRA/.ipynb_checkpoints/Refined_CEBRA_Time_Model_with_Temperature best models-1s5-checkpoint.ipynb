# %%
#! pip install cebra

# %% [markdown]
# # Package

# %%
import sys

import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
import random
import cebra
import cebra.datasets
from cebra import CEBRA
import cebra.grid_search
import time
from collections import Counter
# Out:
# /work/09117/xz6783/ls6/Anaconda/envs/cebra/lib/python3.8/site-packages/cebra/datasets/__init__.py:92: UserWarning: Could not initialize one or more datasets: No module named 'h5py'. For using the datasets, consider installing the [datasets] extension via pip.
#   warnings.warn(f"Could not initialize one or more datasets: {e}. "

# %% [markdown]
# # 1. Dataset

# %%
Dt = pd.read_csv('6S5.csv', index_col=0)

Time = Dt.iloc[:,0]
Y = Dt.iloc[:, 2]
Label = Dt.iloc[:, 1]
X = Dt.iloc[:,3:]

# %% [markdown]
# # 2. Refined Training

# %% [markdown]
# ## (1). Training setting

# %%
# Self define training function
def Self_CEBRA_Time_Training(Toy, X):
    # Timer
    start_time = time.time()

    # DataFrame for evaluation metrics
    Performance = pd.DataFrame([])
    InfoNCE = []

    n_comb = len(Toy)

    for i in range(0, n_comb):
        # Extract hyperparameter
        Hyper_i = Toy.iloc[i, :]
        Hyperpara = {'distance': Hyper_i['distance'],
                     # 'temperature_mode': Hyper_i['temperature_mode'],
                     'time_offsets': Hyper_i['time_offsets'],
                     'batch_size': Hyper_i['batch_size'],
                     'learning_rate': Hyper_i['learning_rate'],
                     'conditional': Hyper_i['conditional'],
                     'output_dimension': Hyper_i['output_dimension'],
                     'num_hidden_units': Hyper_i['num_hidden_units'],
                     'max_iterations': Hyper_i['max_iterations']}

        # Extract sub-hyperparameters
        cebra_time_model = CEBRA(distance = Hyperpara['distance'],
                                 # temperature_mode = Hyperpara['temperature_mode'],
                                 time_offsets = Hyperpara['time_offsets'],
                                 batch_size = Hyperpara['batch_size'],
                                 learning_rate = Hyperpara['learning_rate'],
                                 conditional = Hyperpara['conditional'],
                                 output_dimension = Hyperpara['output_dimension'],
                                 num_hidden_units = Hyperpara['num_hidden_units'],
                                 max_iterations = Hyperpara['max_iterations'],
                                 device = 'cuda_if_available',
                                 verbose = True)

        # Model fitting
        cebra_time_model.fit(X)

        # Model loss function value
        InfoNCELoss = min(cebra_time_model.state_dict_['loss'])
        InfoNCE.append(InfoNCELoss.tolist())

    print("--- %s seconds ---" % (time.time() - start_time))

    # Training performance
    dt = {'Accuracy_Testing': InfoNCE}
    Performance = pd.DataFrame(dt)

    # Combined train and test results
    Combined_Rsult = pd.concat([Toy, Performance], axis = 1)
    return(Combined_Rsult)

# %%
distance = ['cosine']
#temperature_mode = ['auto', 0.001, 0.01, 0.1, 0.5]
temperature = [1]
time_offsets = [10]
batch_size = [None]
learning_rate = [0.0001, 0.001, 0.01, 0.1, 1]
conditional = ['time']
output_dimension = [2, 3, 5, 10, 15]
num_hidden_units = [32, 50, 75]
max_iterations = [10000]


# Put into a matrix
Hyperparameter_Space = [(a,b, c,d, e,f,g,h,i)
                        for a in distance
                        for b in temperature
                        for c in time_offsets
                        for d in batch_size
                        for e in learning_rate
                        for f in conditional
                        for g in output_dimension
                        for h in num_hidden_units
                        for i in max_iterations]
Hyperparameter_Mat = pd.DataFrame(Hyperparameter_Space)
Hyperparameter_Mat.columns = ['distance', 'temperature', 'time_offsets', 'batch_size',
                              'learning_rate', 'conditional', 'output_dimension', 'num_hidden_units', 'max_iterations']
Hyperparameter_Mat
# Out:
#    distance  temperature  time_offsets batch_size  learning_rate conditional  \
# 0    cosine            1            10       None         0.0001        time
# 1    cosine            1            10       None         0.0001        time
# 2    cosine            1            10       None         0.0001        time
# 3    cosine            1            10       None         0.0001        time
# 4    cosine            1            10       None         0.0001        time
# ..      ...          ...           ...        ...            ...         ...
# 70   cosine            1            10       None         1.0000        time
# 71   cosine            1            10       None         1.0000        time
# 72   cosine            1            10       None         1.0000        time
# 73   cosine            1            10       None         1.0000        time
# 74   cosine            1            10       None         1.0000        time
#
#     output_dimension  num_hidden_units  max_iterations
# 0                  2                32           10000
# 1                  2                50           10000
# 2                  2                75           10000
# 3                  3                32           10000
# 4                  3                50           10000
# ..               ...               ...             ...
# 70                10                50           10000
# 71                10                75           10000
# 72                15                32           10000
# 73                15                50           10000
# 74                15                75           10000
#
# [75 rows x 9 columns]

# %% [markdown]
# ## (2). Training procedure

# %%
# Cut hyperparameter space into difference pieces: 5 pieces (0-4)
Hyp_Pieces = np.array_split(range(len(Hyperparameter_Mat)), 5)

# %%
# Batch 0
Toy0 = Hyperparameter_Mat.iloc[Hyp_Pieces[0], :]
Toy0.reset_index(drop=True, inplace=True)
Result_0 = Self_CEBRA_Time_Training(Toy0, X)
Result_0.to_csv('CEBRA_Time Training Results 0 6S5.csv')
# Out:
# pos:  0.0888 neg:  6.7050 total:  6.7938 temperature:  1.0000: 100%|██████████| 10000/10000 [03:57<00:00, 42.18it/s]
# pos:  0.0398 neg:  6.7017 total:  6.7414 temperature:  1.0000: 100%|██████████| 10000/10000 [04:11<00:00, 39.75it/s]
# pos:  0.3342 neg:  6.8324 total:  7.1666 temperature:  1.0000:   2%|▏         | 196/10000 [00:05<04:32, 35.98it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# pos:  0.0182 neg:  6.7012 total:  6.7193 temperature:  1.0000: 100%|██████████| 10000/10000 [04:35<00:00, 36.29it/s]
# pos:  0.2639 neg:  6.6620 total:  6.9259 temperature:  1.0000:  13%|█▎        | 1329/10000 [00:33<03:45, 38.53it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# pos:  0.1230 neg:  6.6370 total:  6.7601 temperature:  1.0000:  26%|██▌       | 2565/10000 [01:06<03:07, 39.59it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# pos:  0.0418 neg:  6.6289 total:  6.6707 temperature:  1.0000: 100%|██████████| 10000/10000 [04:18<00:00, 38.64it/s]
# pos:  0.0254 neg:  6.6271 total:  6.6525 temperature:  1.0000:  61%|██████    | 6069/10000 [02:47<01:49, 36.01it/s]

# %%
# Batch 1
Toy0 = Hyperparameter_Mat.iloc[Hyp_Pieces[1], :]
Toy0.reset_index(drop=True, inplace=True)
Result_0 = Self_CEBRA_Time_Training(Toy0, X)
Result_0.to_csv('CEBRA_Time Training Results 1 6S5.csv')

# %%
# Batch 2
Toy0 = Hyperparameter_Mat.iloc[Hyp_Pieces[2], :]
Toy0.reset_index(drop=True, inplace=True)
Result_0 = Self_CEBRA_Time_Training(Toy0, X)
Result_0.to_csv('CEBRA_Time Training Results 2 6S5.csv')

# %%
# Batch 3
Toy0 = Hyperparameter_Mat.iloc[Hyp_Pieces[3], :]
Toy0.reset_index(drop=True, inplace=True)
Result_0 = Self_CEBRA_Time_Training(Toy0, X)
Result_0.to_csv('CEBRA_Time Training Results 3 6S5.csv')

# %%
# Batch 4
Toy0 = Hyperparameter_Mat.iloc[Hyp_Pieces[4], :]
Toy0.reset_index(drop=True, inplace=True)
Result_0 = Self_CEBRA_Time_Training(Toy0, X)
Result_0.to_csv('CEBRA_Time Training Results 4 6S5.csv')

# %% [markdown]
# # 3. Inference

# %% [markdown]
# ## (1). Best Model

# %%
# Training result
modelPerformence = pd.read_csv('CEBRA_Time Training Results 0 refined.csv')
# Extract min value of convergence
Logic = modelPerformence.loc[:, 'Accuracy_Testing'] == min(modelPerformence.loc[:, 'Accuracy_Testing'])
bestModelPara = modelPerformence[Logic]
bestModelPara
# Out:
#     distance temperature_mode  time_offsets  batch_size  learning_rate  \
# 179   cosine             0.01            10         NaN          0.001
#
#     conditional  output_dimension  num_hidden_units  max_iterations  \
# 179        time                15                75           10000
#
#      Accuracy_Testing
# 179          6.513333

# %% [markdown]
# ## (2). Model Building
# distance = cosine\
# temperature_mode = auto\
# time_offsets = 10\
# batch_size = default\
# learning_rate = 0.001\
# conditional = time\
# output_dimension = 15\
# num_hidden_units = 75\
# max_iterations = 10000

# %%
# Extract sub-hyperparameters
cebra_time_model = CEBRA(distance = 'cosine',
                         # temperature_mode = 'auto',
                         time_offsets = 10,
                         learning_rate = 0.001,
                         conditional = 'time',
                         output_dimension = 15,
                         num_hidden_units = 75,
                         max_iterations = 10000,
                         device = 'cuda_if_available',
                         verbose = True)

# Model fitting
cebra_time_model.fit(X)
# Out:
# pos:  0.0095 neg:  6.5053 total:  6.5149 temperature:  1.0000: 100%|██████████| 10000/10000 [10:42<00:00, 15.57it/s]
# CEBRA(conditional='time', learning_rate=0.001, num_hidden_units=75,
#       output_dimension=15, time_offsets=10, verbose=True)

# %% [markdown]
# ## (3). Inference

# %% [markdown]
# ### a. Model convergence

# %%
# Model convergence
cebra.plot_loss(cebra_time_model)
# Out:
# <Axes: xlabel='Steps', ylabel='InfoNCE Loss'>

# %% [markdown]
# ### b. Embedding vectors

# %%
# Extract embedding vector
embedding = cebra_time_model.transform(X)
# 3D embedding
cebra.plot_embedding(embedding, embedding_labels = "time", markersize=5, alpha=0.5)
# Out:
# <Axes3D: title={'center': 'Embedding'}>

# %%
# 2D embedding
cebra.plot_embedding(embedding, idx_order = (0, 1), embedding_labels = "time", markersize=5, alpha=0.5)
# Out:
# <Axes: title={'center': 'Embedding'}>

# %%
cebra.plot_temperature(cebra_time_model)
# Out:
# <Axes: xlabel='Steps', ylabel='Temperature'>

# %% [markdown]
# ### c. Embedding with labels

# %%
Dt_Embedding = pd.concat([pd.DataFrame(embedding), Label], axis = 1)
Dt_Embedding
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.239628  0.270719  0.376823  0.314456  0.480224 -0.068450 -0.130865
# 1     0.249798  0.273456  0.370622  0.329416  0.481925 -0.071018 -0.123059
# 2     0.244855  0.277791  0.371037  0.328235  0.480453 -0.074848 -0.124232
# 3     0.241609  0.280229  0.378059  0.336937  0.480163 -0.074297 -0.122789
# 4     0.244740  0.280323  0.391451  0.321108  0.478724 -0.068487 -0.124029
# ...        ...       ...       ...       ...       ...       ...       ...
# 1743  0.249610  0.181045  0.057502  0.095989  0.033408 -0.107167  0.617084
# 1744  0.260037  0.170047  0.068356  0.111076  0.032601 -0.077883  0.620327
# 1745  0.253296  0.175276  0.109565  0.108534  0.030861 -0.057509  0.593602
# 1746  0.151995  0.124329  0.347615  0.144300  0.021487  0.165263  0.273207
# 1747  0.079057  0.064305  0.397108  0.135289  0.016434  0.269961  0.053141
#
#              7         8         9        10        11        12        13  \
# 0    -0.327995  0.110811 -0.266589  0.178531  0.187908  0.153516 -0.304053
# 1    -0.305082  0.103447 -0.259014  0.169347  0.200315  0.165842 -0.306368
# 2    -0.310080  0.099506 -0.263446  0.168506  0.201279  0.167537 -0.299318
# 3    -0.303725  0.095811 -0.267498  0.167598  0.186036  0.162794 -0.297730
# 4    -0.312172  0.084530 -0.263452  0.163789  0.173928  0.154278 -0.312373
# ...        ...       ...       ...       ...       ...       ...       ...
# 1743  0.325615 -0.301397  0.003957 -0.290002 -0.181310  0.374198 -0.200662
# 1744  0.343145 -0.275341  0.006932 -0.276732 -0.208593  0.366111 -0.204329
# 1745  0.356953 -0.255203 -0.011665 -0.284057 -0.269170  0.376468 -0.176668
# 1746  0.395605 -0.010276 -0.092225 -0.188631 -0.653920  0.266093  0.019794
# 1747  0.341035  0.141464 -0.105807 -0.091926 -0.726211  0.154501  0.112817
#
#             14              Label
# 0     0.043102    Reward_Baseline
# 1     0.058941    Reward_Baseline
# 2     0.059822    Reward_Baseline
# 3     0.068268    Reward_Baseline
# 4     0.058882    Reward_Baseline
# ...        ...                ...
# 1743  0.069714  Conflict_Baseline
# 1744  0.070929  Conflict_Baseline
# 1745  0.077140  Conflict_Baseline
# 1746  0.133643  Conflict_Baseline
# 1747  0.133045  Conflict_Baseline
#
# [1748 rows x 16 columns]

# %%
x_Reward_Baseline = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Reward_Baseline', 0]
x_Reward_Cue = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Reward_Cue', 0]
x_Threat = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Threat', 0]
x_Conflict_Cue = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Conflict_Cue', 0]
x_Conflict_Baseline = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Conflict_Baseline', 0]

y_Reward_Baseline = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Reward_Baseline', 1]
y_Reward_Cue = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Reward_Cue', 1]
y_Threat = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Threat', 1]
y_Conflict_Cue = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Conflict_Cue', 1]
y_Conflict_Baseline = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Conflict_Baseline', 1]

z_Reward_Baseline = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Reward_Baseline', 2]
z_Reward_Cue = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Reward_Cue', 2]
z_Threat = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Threat', 2]
z_Conflict_Cue = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Conflict_Cue', 2]
z_Conflict_Baseline = Dt_Embedding.loc[Dt_Embedding.loc[:, 'Label'] == 'Conflict_Baseline', 2]

fig = plt.figure(figsize = (10, 10))
ax = plt.axes(projection ="3d")

# Legend
ax.plot(x_Reward_Baseline, y_Reward_Baseline, z_Reward_Baseline, ".", label = "Reward Baseline", color = 'gray', alpha = 0.5)
ax.plot(x_Reward_Cue, y_Reward_Cue, z_Reward_Cue, ".", label = "Reward Cue", color = 'red', alpha = 0.5)
ax.plot(x_Threat, y_Threat, z_Threat, ".", label = "Threat", color = 'blue', alpha = 0.5)
ax.plot(x_Conflict_Cue, y_Conflict_Cue, z_Conflict_Cue, ".", label = "Conflict Cue", color = 'green')
ax.plot(x_Conflict_Baseline, y_Conflict_Baseline, z_Conflict_Baseline, ".", label = "Conflict Baseline", color = 'pink', alpha = 0.5)

# Remove background color
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
# Remove background grid
ax.grid(False)
plt.legend(loc="upper right")
plt.show()
